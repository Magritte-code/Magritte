# %% [markdown]
# # Overview of Analytic Benchmarks
# ---

# %% [markdown]
# ### All constant single ray
# ---

# %%
from all_constant_single_ray import run_test
run_test()
# Out:
# Writing parameters...
# Writing points...
# Writing rays...
# Writing boundary...
# Writing chemistry...
# Writing species...
# Writing thermodynamics...
# Writing temperature...
# Writing turbulence...
# Writing lines...
# Writing lineProducingSpecies...
# Writing linedata...
# ncolpoar = 1
# --- colpoar = 0
# Writing collisionPartner...
# (l, c) = 0, 0
# Writing quadrature...
# Writing populations...
# Writing radiation...
# Writing frequencies...
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /lhome/thomasc/github/Magritte/tests/benchmarks/analytic/../../models/all_constant_single_ray.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 0
# read sym test
# nlev = 2
# nrad = 1
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 50
#   nrays      = 2
#   nboundary  = 2
#   nfreqs     = 1
#   nspecs     = 3
#   nlspecs    = 1
#   nlines     = 1
#   nquads     = 1
# -------------------------------------------
#
# Computing spectral discretisation...
# Computing inverse line widths...
# Computing LTE level populations...
# Computing radiation field...
# --- rr = 0
# Computing radiation field...
# --- rr = 0
# MPI gathering J...
# Done MPI gathering J.
# MPI gathering Lambda...
# Done MPI gathering Lambda.
# Computing radiation field...
# --- rr = 0
# --- Benchmark name ----------------------------
# all_constant_single_ray
# --- Parameters --------------------------------
# dimension = 1
# npoints   = 50
# nrays     = 2
# nquads    = 1
# --- Accuracy ----------------------------------
# max error in shortchar 0 = 5.0662308346852514e-08
# max error in feautrier 2 = 0.00015836367001114784
# max error in I_0 2f uv = 0.00019995683663766255
# max error in I_1 2f uv = 0.000199956836637877
# --- Timers ------------------------------------
# timer: reading model = 0.3694398320003529
# timer: setting model = 0.10690117499325424
# timer: shortchar 0   = 0.8203736689974903
# timer: feautrier 2   = 0.8355408839997835
# -----------------------------------------------

# %% [markdown]
# ### Constant velocity gradient 1D
# ---

# %%
from constant_velocity_gradient_1D import run_test
run_test()
# Out:
# Writing parameters...
# Writing points...
# Writing rays...
# Writing boundary...
# Writing chemistry...
# Writing species...
# Writing thermodynamics...
# Writing temperature...
# Writing turbulence...
# Writing lines...
# Writing lineProducingSpecies...
# Writing linedata...
# ncolpoar = 1
# --- colpoar = 0
# Writing collisionPartner...
# (l, c) = 0, 0
# Writing quadrature...
# Writing populations...
# Writing radiation...
# Writing frequencies...
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /lhome/thomasc/github/Magritte/tests/benchmarks/analytic/../../models/constant_velocity_gradient_1D.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 0
# read sym test
# nlev = 2
# nrad = 1
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 100
#   nrays      = 100
#   nboundary  = 2
#   nfreqs     = 100
#   nspecs     = 3
#   nlspecs    = 1
#   nlines     = 1
#   nquads     = 100
# -------------------------------------------
#
# Computing spectral discretisation...
# Computing inverse line widths...
# Computing LTE level populations...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# --- rr = 24
# --- rr = 25
# --- rr = 26
# --- rr = 27
# --- rr = 28
# --- rr = 29
# --- rr = 30
# --- rr = 31
# --- rr = 32
# --- rr = 33
# --- rr = 34
# --- rr = 35
# --- rr = 36
# --- rr = 37
# --- rr = 38
# --- rr = 39
# --- rr = 40
# --- rr = 41
# --- rr = 42
# --- rr = 43
# --- rr = 44
# --- rr = 45
# --- rr = 46
# --- rr = 47
# --- rr = 48
# --- rr = 49
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# --- rr = 24
# --- rr = 25
# --- rr = 26
# --- rr = 27
# --- rr = 28
# --- rr = 29
# --- rr = 30
# --- rr = 31
# --- rr = 32
# --- rr = 33
# --- rr = 34
# --- rr = 35
# --- rr = 36
# --- rr = 37
# --- rr = 38
# --- rr = 39
# --- rr = 40
# --- rr = 41
# --- rr = 42
# --- rr = 43
# --- rr = 44
# --- rr = 45
# --- rr = 46
# --- rr = 47
# --- rr = 48
# --- rr = 49
# MPI gathering J...
# Done MPI gathering J.
# MPI gathering Lambda...
# Done MPI gathering Lambda.
# interactive(children=(IntSlider(value=24, description='r', max=49), IntSlider(value=49, description='p', max=9…
# --- Benchmark name ------------------------------
# constant_velocity_gradient_1D
# --- Parameters ----------------------------------
# dimension = 1
# npoints   = 100
# nrays     = 100
# nquads    = 100
# --- Accuracy ------------------------------------
# mean error in shortchar 0 = 4.863484834525203e-07
# mean error in feautrier 2 = 4.4619389982118183e-07
# --- Timers --------------------------------------
# timer: reading model = 0.4491564640047727
# timer: setting model = 0.11407089100248413
# timer: shortchar 0   = 2.813188417996571
# timer: feautrier 2   = 1.4050208640037454
# -------------------------------------------------

# %% [markdown]
# ### Constant velocity gradient 1D image
# ---

# %%
from constant_velocity_gradient_1D_image import run_test
run_test()
# Out:
# Writing parameters...
# Writing points...
# Writing rays...
# Writing boundary...
# Writing chemistry...
# Writing species...
# Writing thermodynamics...
# Writing temperature...
# Writing turbulence...
# Writing lines...
# Writing lineProducingSpecies...
# Writing linedata...
# ncolpoar = 1
# --- colpoar = 0
# Writing collisionPartner...
# (l, c) = 0, 0
# Writing quadrature...
# Writing populations...
# Writing radiation...
# Writing frequencies...
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /lhome/thomasc/github/Magritte/tests/benchmarks/analytic/../../models/constant_velocity_gradient_1D_image.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 0
# read sym test
# nlev = 2
# nrad = 1
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 100
#   nrays      = 4
#   nboundary  = 2
#   nfreqs     = 100
#   nspecs     = 3
#   nlspecs    = 1
#   nlines     = 1
#   nquads     = 100
# -------------------------------------------
#
# Computing spectral discretisation...
# Computing inverse line widths...
# Computing LTE level populations...
# Computing image...
# interactive(children=(IntSlider(value=49, description='p', max=99), Output()), _dom_classes=('widget-interact'…
# --- Benchmark name ------------------------------
# constant_velocity_gradient_1D_image
# --- Parameters ----------------------------------
# dimension = 1
# npoints   = 100
# nrays     = 4
# nquads    = 100
# --- Accuracy ------------------------------------
# max error in imager = 1.5962208253782377e-05
# --- Timers --------------------------------------
# timer: reading model = 0.33056174000375904
# timer: setting model = 0.10778431699873181
# timer: image         = 0.7469711739977356
# -------------------------------------------------

# %% [markdown]
# ### Density distribution single ray
# ---

# %%
from density_distribution_single_ray import run_test
run_test()
# Out:
# Writing parameters...
# Writing points...
# Writing rays...
# Writing boundary...
# Writing chemistry...
# Writing species...
# Writing thermodynamics...
# Writing temperature...
# Writing turbulence...
# Writing lines...
# Writing lineProducingSpecies...
# Writing linedata...
# ncolpoar = 1
# --- colpoar = 0
# Writing collisionPartner...
# (l, c) = 0, 0
# Writing quadrature...
# Writing populations...
# Writing radiation...
# Writing frequencies...
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /lhome/thomasc/github/Magritte/tests/benchmarks/analytic/../../models/density_distribution_VZa_single_ray.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 0
# read sym test
# nlev = 2
# nrad = 1
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 200
#   nrays      = 2
#   nboundary  = 2
#   nfreqs     = 1
#   nspecs     = 3
#   nlspecs    = 1
#   nlines     = 1
#   nquads     = 1
# -------------------------------------------
#
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /lhome/thomasc/github/Magritte/tests/benchmarks/analytic/../../models/density_distribution_VZa_single_ray.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 0
# read sym test
# nlev = 2
# nrad = 1
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 200
#   nrays      = 2
#   nboundary  = 2
#   nfreqs     = 1
#   nspecs     = 3
#   nlspecs    = 1
#   nlines     = 1
#   nquads     = 1
# -------------------------------------------
#
# Computing spectral discretisation...
# Computing inverse line widths...
# Computing LTE level populations...
# Computing radiation field...
# --- rr = 0
# Computing radiation field...
# --- rr = 0
# MPI gathering J...
# Done MPI gathering J.
# MPI gathering Lambda...
# Done MPI gathering Lambda.
# --- Benchmark name ----------------------------
# density_distribution_VZa_single_ray
# --- Parameters --------------------------------
# dimension = 1
# npoints   = 200
# nrays     = 2
# nquads    = 1
# --- Accuracy ----------------------------------
# max error in shortchar 0 = 0.004920184942899274
# mean error in shortchar 0 = 0.00028483117751666465
# max error in feautrier 2 = 0.01641730151935746
# mean error in feautrier 2 = 0.0003947239852953095
# --- Timers ------------------------------------
# timer: reading model = 0.43542905600043014
# timer: setting model = 0.09785757500503678
# timer: shortchar 0   = 1.0219852549998905
# timer: feautrier 2   = 0.6701935890014283
# -----------------------------------------------
#
# Writing parameters...
# Writing points...
# Writing rays...
# Writing boundary...
# Writing chemistry...
# Writing species...
# Writing thermodynamics...
# Writing temperature...
# Writing turbulence...
# Writing lines...
# Writing lineProducingSpecies...
# Writing linedata...
# ncolpoar = 1
# --- colpoar = 0
# Writing collisionPartner...
# (l, c) = 0, 0
# Writing quadrature...
# Writing populations...
# Writing radiation...
# Writing frequencies...
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /lhome/thomasc/github/Magritte/tests/benchmarks/analytic/../../models/density_distribution_VZb_single_ray.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 0
# read sym test
# nlev = 2
# nrad = 1
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 200
#   nrays      = 2
#   nboundary  = 2
#   nfreqs     = 1
#   nspecs     = 3
#   nlspecs    = 1
#   nlines     = 1
#   nquads     = 1
# -------------------------------------------
#
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /lhome/thomasc/github/Magritte/tests/benchmarks/analytic/../../models/density_distribution_VZb_single_ray.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 0
# read sym test
# nlev = 2
# nrad = 1
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 200
#   nrays      = 2
#   nboundary  = 2
#   nfreqs     = 1
#   nspecs     = 3
#   nlspecs    = 1
#   nlines     = 1
#   nquads     = 1
# -------------------------------------------
#
# Computing spectral discretisation...
# Computing inverse line widths...
# Computing LTE level populations...
# Computing radiation field...
# --- rr = 0
# Computing radiation field...
# --- rr = 0
# MPI gathering J...
# Done MPI gathering J.
# MPI gathering Lambda...
# Done MPI gathering Lambda.
# --- Benchmark name ----------------------------
# density_distribution_VZb_single_ray
# --- Parameters --------------------------------
# dimension = 1
# npoints   = 200
# nrays     = 2
# nquads    = 1
# --- Accuracy ----------------------------------
# max error in shortchar 0 = 0.00022792418435822553
# mean error in shortchar 0 = 5.2392299572042576e-05
# max error in feautrier 2 = 0.6142758236268978
# mean error in feautrier 2 = 0.003148052583112931
# --- Timers ------------------------------------
# timer: reading model = 0.4571898619979038
# timer: setting model = 0.11162384999624919
# timer: shortchar 0   = 1.0405200679961126
# timer: feautrier 2   = 0.9965827129999525
# -----------------------------------------------

# %% [markdown]
# ### Density distribution 1D
# ---

# %%
from density_distribution_1D import run_test
run_test()
# Out:
# Writing parameters...
# Writing points...
# Writing rays...
# Writing boundary...
# Writing chemistry...
# Writing species...
# Writing thermodynamics...
# Writing temperature...
# Writing turbulence...
# Writing lines...
# Writing lineProducingSpecies...
# Writing linedata...
# ncolpoar = 1
# --- colpoar = 0
# Writing collisionPartner...
# (l, c) = 0, 0
# Writing quadrature...
# Writing populations...
# Writing radiation...
# Writing frequencies...
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /lhome/thomasc/github/Magritte/tests/benchmarks/analytic/../../models/density_distribution_VZa_1D.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 0
# read sym test
# nlev = 2
# nrad = 1
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 200
#   nrays      = 50
#   nboundary  = 2
#   nfreqs     = 50
#   nspecs     = 3
#   nlspecs    = 1
#   nlines     = 1
#   nquads     = 50
# -------------------------------------------
#
# Computing spectral discretisation...
# Computing inverse line widths...
# Computing LTE level populations...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# --- rr = 24
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# --- rr = 24
# MPI gathering J...
# Done MPI gathering J.
# MPI gathering Lambda...
# Done MPI gathering Lambda.
# /lhome/thomasc/github/Magritte/tests/benchmarks/analytic/density_distribution_1D.py:165: RuntimeWarning: invalid value encountered in arccos
#   factor = np.arccos(r*np.sin(theta)/r_out) + 0.5*np.pi - theta
# interactive(children=(IntSlider(value=12, description='r', max=24), IntSlider(value=99, description='p', max=1…
# --- Benchmark name ------------------------------
# density_distribution_VZa_1D
# --- Parameters ----------------------------------
# dimension = 1
# npoints   = 200
# nrays     = 50
# nquads    = 50
# --- Accuracy ------------------------------------
# mean error in shortchar 0 = 0.0004084871365943026
# mean error in feautrier 2 = 0.00043158108389392685
# --- Timers --------------------------------------
# timer: reading model = 0.41517820800072514
# timer: setting model = 0.08285418699961156
# timer: shortchar 0   = 1.6939222459986922
# timer: feautrier 2   = 2.027618406995316
# -------------------------------------------------
#
# Writing parameters...
# Writing points...
# Writing rays...
# Writing boundary...
# Writing chemistry...
# Writing species...
# Writing thermodynamics...
# Writing temperature...
# Writing turbulence...
# Writing lines...
# Writing lineProducingSpecies...
# Writing linedata...
# ncolpoar = 1
# --- colpoar = 0
# Writing collisionPartner...
# (l, c) = 0, 0
# Writing quadrature...
# Writing populations...
# Writing radiation...
# Writing frequencies...
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /lhome/thomasc/github/Magritte/tests/benchmarks/analytic/../../models/density_distribution_VZb_1D.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 0
# read sym test
# nlev = 2
# nrad = 1
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 200
#   nrays      = 50
#   nboundary  = 2
#   nfreqs     = 50
#   nspecs     = 3
#   nlspecs    = 1
#   nlines     = 1
#   nquads     = 50
# -------------------------------------------
#
# Computing spectral discretisation...
# Computing inverse line widths...
# Computing LTE level populations...
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# --- rr = 24
# Computing radiation field...
# --- rr = 0
# --- rr = 1
# --- rr = 2
# --- rr = 3
# --- rr = 4
# --- rr = 5
# --- rr = 6
# --- rr = 7
# --- rr = 8
# --- rr = 9
# --- rr = 10
# --- rr = 11
# --- rr = 12
# --- rr = 13
# --- rr = 14
# --- rr = 15
# --- rr = 16
# --- rr = 17
# --- rr = 18
# --- rr = 19
# --- rr = 20
# --- rr = 21
# --- rr = 22
# --- rr = 23
# --- rr = 24
# MPI gathering J...
# Done MPI gathering J.
# MPI gathering Lambda...
# Done MPI gathering Lambda.
# interactive(children=(IntSlider(value=12, description='r', max=24), IntSlider(value=99, description='p', max=1…
# /lhome/thomasc/github/Magritte/tests/benchmarks/analytic/density_distribution_1D.py:195: RuntimeWarning: divide by zero encountered in log10
#   log_err_min = np.log10(np.min([error_u_0s, error_u_2f]))
# /lhome/thomasc/github/Magritte/dependencies/miniconda3/envs/magritte/lib/python3.10/site-packages/numpy/core/function_base.py:157: RuntimeWarning: invalid value encountered in multiply
#   y *= step
# /lhome/thomasc/github/Magritte/dependencies/miniconda3/envs/magritte/lib/python3.10/site-packages/numpy/core/function_base.py:167: RuntimeWarning: invalid value encountered in add
#   y += start
# --- Benchmark name ------------------------------
# density_distribution_VZb_1D
# --- Parameters ----------------------------------
# dimension = 1
# npoints   = 200
# nrays     = 50
# nquads    = 50
# --- Accuracy ------------------------------------
# mean error in shortchar 0 = 0.0002588654467510552
# mean error in feautrier 2 = 0.0009325618388075748
# --- Timers --------------------------------------
# timer: reading model = 0.4257647830017959
# timer: setting model = 0.11731763699935982
# timer: shortchar 0   = 1.986254175004433
# timer: feautrier 2   = 1.8031054140010383
# -------------------------------------------------

# %% [markdown]
# ### Density distribution 1D image
# ---

# %%
from density_distribution_1D_image import run_test
run_test()
# Out:
# Writing parameters...
# Writing points...
# Writing rays...
# Writing boundary...
# Writing chemistry...
# Writing species...
# Writing thermodynamics...
# Writing temperature...
# Writing turbulence...
# Writing lines...
# Writing lineProducingSpecies...
# Writing linedata...
# ncolpoar = 1
# --- colpoar = 0
# Writing collisionPartner...
# (l, c) = 0, 0
# Writing quadrature...
# Writing populations...
# Writing radiation...
# Writing frequencies...
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /lhome/thomasc/github/Magritte/tests/benchmarks/analytic/../../models/density_distribution_VZa_1D_image.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 0
# read sym test
# nlev = 2
# nrad = 1
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 200
#   nrays      = 50
#   nboundary  = 2
#   nfreqs     = 50
#   nspecs     = 3
#   nlspecs    = 1
#   nlines     = 1
#   nquads     = 50
# -------------------------------------------
#
# Computing spectral discretisation...
# Computing inverse line widths...
# Computing LTE level populations...
# Computing image...
# /lhome/thomasc/github/Magritte/tests/benchmarks/analytic/density_distribution_1D_image.py:150: RuntimeWarning: invalid value encountered in arccos
#   factor = np.arccos(r*np.sin(theta)/r_out) + 0.5*np.pi - theta
# interactive(children=(IntSlider(value=99, description='p', max=199), Output()), _dom_classes=('widget-interact…
# --- Benchmark name ------------------------------
# density_distribution_VZa_1D_image
# --- Parameters ----------------------------------
# dimension = 1
# npoints   = 200
# nrays     = 50
# nquads    = 50
# --- Accuracy ------------------------------------
# max error in imager = 0.014109706293922056
# --- Timers --------------------------------------
# timer: reading model = 0.46875954500137595
# timer: setting model = 0.11609283999860054
# timer: image         = 0.8762062139940099
# -------------------------------------------------

# %% [markdown]
# # Notes

# %%
import sys, os
curdir = os.path.dirname(os.path.realpath('__file__'))
datdir = f'{curdir}/../../data/'
moddir = f'{curdir}/../../models/'
resdir = f'{curdir}/../../results/'
sys.path.append(f'{curdir}/../../../')

import magritte.core as magritte
import magritte.tools as tools

# %%
import numpy             as np
import matplotlib.pyplot as plt
import ipywidgets        as widgets

# %%
curdir
# Out:
# '/lhome/thomasc/github/Magritte/tests/benchmarks/analytic'

# %%
from density_distribution_1D_image import create_model, run_model

# %%
model = create_model('b')
# Out:
# Writing parameters...
# Writing points...
# Writing rays...
# Writing boundary...
# Writing chemistry...
# Writing species...
# Writing thermodynamics...
# Writing temperature...
# Writing turbulence...
# Writing lines...
# Writing lineProducingSpecies...
# Writing linedata...
# ncolpoar = 1
# --- colpoar = 0
# Writing collisionPartner...
# (l, c) = 0, 0
# Writing quadrature...
# Writing populations...
# Writing radiation...
# Writing frequencies...

# %%
run_model ('b')
# Out:
#
# -------------------------------------------
#   Reading Model...
# -------------------------------------------
#  model file = /lhome/thomasc/github/Magritte/tests/benchmarks/analytic/../../models/density_distribution_VZb_1D_image.hdf5
# -------------------------------------------
# Reading parameters...
# Reading points...
# Reading rays...
# Reading boundary...
# Reading chemistry...
# Reading species...
# Reading thermodynamics...
# Reading temperature...
# Reading turbulence...
# Reading lines...
# Reading lineProducingSpecies...
# Reading linedata...
# read num 1
# read sym test
# nlev = 2
# nrad = 1
# Reading collisionPartner...
# Reading quadrature...
# Reading radiation...
# Reading frequencies...
# Not using scattering!
#
# -------------------------------------------
#   Model read, parameters:
# -------------------------------------------
#   npoints    = 200
#   nrays      = 50
#   nboundary  = 2
#   nfreqs     = 50
#   nspecs     = 5
#   nlspecs    = 1
#   nlines     = 1
#   nquads     = 50
# -------------------------------------------
#
# Computing spectral discretisation...
# Computing inverse line widths...
# Computing LTE level populations...
# Computing image...
# interactive(children=(IntSlider(value=99, description='p', max=199), Output()), _dom_classes=('widget-interact…
# --- Benchmark name ------------------------------
# density_distribution_VZb_1D_image
# --- Parameters ----------------------------------
# dimension = 1
# npoints   = 200
# nrays     = 50
# nquads    = 50
# --- Accuracy ------------------------------------
# max error in imager = 0.010281665500207373
# --- Timers --------------------------------------
# timer: reading model = 0.02533197301090695
# timer: setting model = 0.00021678899065591395
# timer: image         = 0.014659776992630213
# -------------------------------------------------

# %%
npoints = im.shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 npoints = im.shape[0]
#
# NameError: name 'im' is not defined

# %%
ld = model.lines.lineProducingSpecies[0].linedata

k = 0

frq = ld.frequency[k]
pop = tools.LTEpop         (ld, temp) * X_mol * nH2_in
eta = tools.lineEmissivity (ld, pop)[k]
chi = tools.lineOpacity    (ld, pop)[k]
src = tools.lineSource     (ld, pop)[k]


def phi (nu):
    return tools.profile (ld, k, temp, (turb/magritte.CC)**2, nu)

def bdy (nu):
    return tools.I_CMB (nu)

def tau (nu, r, theta):
    pref = chi * phi(nu) * r_in**2
    if (theta == 0.0):
        return pref * (2.0/r_in - 1.0/r - 1.0/r_out)
    if (theta == np.pi):
        return pref * (1.0/r - 1.0/r_out)
    else:
        factor = np.arccos(r*np.sin(theta)/r_out) + 0.5*np.pi - theta
        # if (theta < np.arcsin(r_in/r)):
            # factor = factor - np.arccos(r*np.sin(theta)/r_in)
        return pref / (r*np.sin(theta)) * factor

def I_im (nu, r):
    return src + (bdy(nu)-src)*np.exp(-2.0*tau(nu, r, 0.5*np.pi))

im = np.array([[I_im(f,r) for f in nu] for r in rs])

# %%
error = np.abs(tools.relative_error(im, im_a))[:-1]
np.max(error)

# %%
err

# %%
def plot(p):
    plt.plot(im  [p], marker='.')
    plt.plot(im_a[p])
    
widgets.interact(plot, p=(0,npoints-1,1))

# %%
from constant_velocity_gradient_1D import create_model, run_model

# %%
model = create_model()

# %%
run_model()

# %%
tools.relative_error(im, im_a)
