# %% [markdown]
# # Overview of Analytic Benchmarks
# ---

# %% [markdown]
# ### All constant single ray
# ---

# %%
from all_constant_single_ray import run_test
run_test()
# Out:
# --- Benchmark name ----------------------------
# all_constant_single_ray
# --- Parameters --------------------------------
# dimension = 1
# npoints   = 50
# nrays     = 2
# nquads    = 1
# --- Accuracy ----------------------------------
# max error in shortchar 0 = 0.03197139339436923
# max error in feautrier 2 = 6.544341240505151e-06
# --- Timers ------------------------------------
# timer: reading model = 0.044680536000669235
# timer: setting model = 0.00024839400066412054
# timer: shortchar 0   = 0.001455354000427178
# timer: feautrier 2   = 0.0014259189993026666
# -----------------------------------------------

# %% [markdown]
# ### Constant velocity gradient 1D
# ---

# %%
from constant_velocity_gradient_1D import run_test
run_test()
# Out:
# interactive(children=(IntSlider(value=24, description='r', max=49), IntSlider(value=49, description='p', max=9…
# --- Benchmark name ------------------------------
# constant_velocity_gradient_1D
# --- Parameters ----------------------------------
# dimension = 1
# npoints   = 100
# nrays     = 100
# nquads    = 100
# --- Accuracy ------------------------------------
# mean error in shortchar 0 = 7.109001958386879e-05
# mean error in feautrier 2 = 2.237325094160245e-05
# --- Timers --------------------------------------
# timer: reading model = 0.06334935500126448
# timer: setting model = 0.000603786000283435
# timer: shortchar 0   = 1.4171626810020825
# timer: feautrier 2   = 1.8531753899987962
# -------------------------------------------------

# %% [markdown]
# ### Constant velocity gradient 1D image
# ---

# %%
from constant_velocity_gradient_1D_image import run_test
run_test()
# Out:
# interactive(children=(IntSlider(value=49, description='p', max=99), Output()), _dom_classes=('widget-interact'…
# --- Benchmark name ------------------------------
# constant_velocity_gradient_1D_image
# --- Parameters ----------------------------------
# dimension = 1
# npoints   = 100
# nrays     = 4
# nquads    = 100
# --- Accuracy ------------------------------------
# max error in imager = 0.0011929679238946126
# --- Timers --------------------------------------
# timer: reading model = 0.06206817400016007
# timer: setting model = 0.0057190989991795504
# timer: image         = 0.2686504400007834
# -------------------------------------------------

# %% [markdown]
# ### Density distribution single ray
# ---

# %%
from density_distribution_single_ray import run_test
run_test()
# Out:
# --- Benchmark name ----------------------------
# density_distribution_VZa_single_ray
# --- Parameters --------------------------------
# dimension = 1
# npoints   = 200
# nrays     = 2
# nquads    = 1
# --- Accuracy ----------------------------------
# max error in shortchar 0 = 0.2523540892920502
# max error in feautrier 2 = 0.0005212261660888235
# --- Timers ------------------------------------
# timer: reading model = 0.0576268370004982
# timer: setting model = 0.0016448010010208236
# timer: shortchar 0   = 0.021549473000050057
# timer: feautrier 2   = 0.010593723998681526
# -----------------------------------------------
#
# --- Benchmark name ----------------------------
# density_distribution_VZb_single_ray
# --- Parameters --------------------------------
# dimension = 1
# npoints   = 200
# nrays     = 2
# nquads    = 1
# --- Accuracy ----------------------------------
# max error in shortchar 0 = 2.0
# max error in feautrier 2 = 1.1660503383627957e-05
# --- Timers ------------------------------------
# timer: reading model = 0.04950840300080017
# timer: setting model = 0.0013593990006484091
# timer: shortchar 0   = 0.013242563998574042
# timer: feautrier 2   = 0.008849492000081227
# -----------------------------------------------

# %% [markdown]
# ### Density distribution 1D
# ---

# %%
from density_distribution_1D import run_test
run_test()
# Out:
# /home/frederik/Dropbox/GitHub/Magritte/tests/benchmarks/analytic/density_distribution_1D.py:150: RuntimeWarning: invalid value encountered in arccos
#   factor = np.arccos(r*np.sin(theta)/r_out) + 0.5*np.pi - theta
# --- Benchmark name ------------------------------
# density_distribution_VZa_1D
# --- Parameters ----------------------------------
# dimension = 1
# npoints   = 200
# nrays     = 50
# nquads    = 50
# --- Accuracy ------------------------------------
# mean error in shortchar 0 = 0.0256408213736339
# mean error in feautrier 2 = 0.01491583355939728
# --- Timers --------------------------------------
# timer: reading model = 0.062106531999233994
# timer: setting model = 0.0022731329991074745
# timer: shortchar 0   = 2.667947832000209
# timer: feautrier 2   = 3.6485593849993165
# -------------------------------------------------
# /home/frederik/Dropbox/GitHub/Magritte/tests/benchmarks/analytic/density_distribution_1D.py:150: RuntimeWarning: invalid value encountered in arccos
#   factor = np.arccos(r*np.sin(theta)/r_out) + 0.5*np.pi - theta
# --- Benchmark name ------------------------------
# density_distribution_VZb_1D
# --- Parameters ----------------------------------
# dimension = 1
# npoints   = 200
# nrays     = 50
# nquads    = 50
# --- Accuracy ------------------------------------
# mean error in shortchar 0 = 0.17931704069286836
# mean error in feautrier 2 = 0.009994547560944018
# --- Timers --------------------------------------
# timer: reading model = 0.10502795600041281
# timer: setting model = 0.0026084660003107274
# timer: shortchar 0   = 2.892236601001059
# timer: feautrier 2   = 3.692815333000908
# -------------------------------------------------

# %% [markdown]
# ### Density distribution 1D image
# ---

# %%
from density_distribution_1D_image import run_test
run_test()
# Out:
# /home/frederik/Dropbox/GitHub/Magritte/tests/benchmarks/analytic/density_distribution_1D_image.py:152: RuntimeWarning: invalid value encountered in arccos
#   factor = np.arccos(r*np.sin(theta)/r_out) + 0.5*np.pi - theta
# interactive(children=(IntSlider(value=99, description='p', max=199), Output()), _dom_classes=('widget-interact…
# --- Benchmark name ------------------------------
# density_distribution_VZa_1D_image
# --- Parameters ----------------------------------
# dimension = 1
# npoints   = 200
# nrays     = 50
# nquads    = 50
# --- Accuracy ------------------------------------
# max error in imager = 0.0017921695692330823
# --- Timers --------------------------------------
# timer: reading model = 0.07237953200092306
# timer: setting model = 0.001799267000023974
# timer: image         = 0.2562861449987395
# -------------------------------------------------

# %% [markdown]
# # Notes

# %%
import sys, os
curdir = os.path.dirname(os.path.realpath('__file__'))
datdir = f'{curdir}/../../data/'
moddir = f'{curdir}/../../models/'
resdir = f'{curdir}/../../results/'
sys.path.append(f'{curdir}/../../../')

import magritte.core as magritte
import magritte.tools as tools

# %%
import numpy             as np
import matplotlib.pyplot as plt
import ipywidgets        as widgets

# %%
curdir
# Out:
# '/home/frederik/Dropbox/GitHub/Magritte/tests/benchmarks/analytic'

# %%
from density_distribution_1D_image import create_model, run_model

# %%
model = create_model('b')

# %%
run_model ('b')
# Out:
# /home/frederik/Dropbox/GitHub/Magritte/tests/benchmarks/analytic/density_distribution_1D_image.py:152: RuntimeWarning: invalid value encountered in arccos
#   factor = np.arccos(r*np.sin(theta)/r_out) + 0.5*np.pi - theta
# --- Benchmark name ------------------------------
# density_distribution_VZb_1D_image
# --- Parameters ----------------------------------
# dimension = 1
# npoints   = 200
# nrays     = 50
# nquads    = 50
# --- Accuracy ------------------------------------
# max error in imager = 0.010292879350172994
# --- Timers --------------------------------------
# timer: reading model = 0.08918232499854639
# timer: setting model = 0.001796676002413733
# timer: image         = 0.20179906900011702
# -------------------------------------------------

# %%
npoints = im.shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-524b46ecfc3f> in <module>
# ----> 1 npoints = im.shape[0]
#
# NameError: name 'im' is not defined

# %%
ld = model.lines.lineProducingSpecies[0].linedata

k = 0

frq = ld.frequency[k]
pop = tools.LTEpop         (ld, temp) * X_mol * nH2_in
eta = tools.lineEmissivity (ld, pop)[k]
chi = tools.lineOpacity    (ld, pop)[k]
src = tools.lineSource     (ld, pop)[k]


def phi (nu):
    return tools.profile (ld, k, temp, (turb/magritte.CC)**2, nu)

def bdy (nu):
    return tools.I_CMB (nu)

def tau (nu, r, theta):
    pref = chi * phi(nu) * r_in**2
    if (theta == 0.0):
        return pref * (2.0/r_in - 1.0/r - 1.0/r_out)
    if (theta == np.pi):
        return pref * (1.0/r - 1.0/r_out)
    else:
        factor = np.arccos(r*np.sin(theta)/r_out) + 0.5*np.pi - theta
        # if (theta < np.arcsin(r_in/r)):
            # factor = factor - np.arccos(r*np.sin(theta)/r_in)
        return pref / (r*np.sin(theta)) * factor

def I_im (nu, r):
    return src + (bdy(nu)-src)*np.exp(-2.0*tau(nu, r, 0.5*np.pi))

im = np.array([[I_im(f,r) for f in nu] for r in rs])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-67fffe75ba0d> in <module>
#       4
#       5 frq = ld.frequency[k]
# ----> 6 pop = tools.LTEpop         (ld, temp) * X_mol * nH2_in
#       7 eta = tools.lineEmissivity (ld, pop)[k]
#       8 chi = tools.lineOpacity    (ld, pop)[k]
#
# NameError: name 'temp' is not defined

# %%
error = np.abs(tools.relative_error(im, im_a))[:-1]
np.max(error)
# Out:
# 0.001792520799786964885

# %%
err

# %%
def plot(p):
    plt.plot(im  [p], marker='.')
    plt.plot(im_a[p])
    
widgets.interact(plot, p=(0,npoints-1,1))
# Out:
# interactive(children=(IntSlider(value=99, description='p', max=199), Output()), _dom_classes=('widget-interact…
# <function __main__.plot(p)>

# %%
from constant_velocity_gradient_1D import create_model, run_model

# %%
model = create_model()
# Out:
# /home/frederik/Dropbox/GitHub/Magritte/tests/benchmarks/analytic/../../../magritte/setup.py:128: RuntimeWarning: divide by zero encountered in double_scalars
#   angle_extra = (0.5*np.pi - angle_max) / nextra

# %%
run_model()
# Out:
# --- Benchmark name ------------------------------
# constant_velocity_gradient_1D
# --- Parameters ----------------------------------
# dimension = 1
# npoints   = 100
# nrays     = 2
# nquads    = 100
# --- Accuracy ------------------------------------
# mean error in shortchar 0 = 0.00012309066377132256
# mean error in feautrier 2 = 0.0001282573764872311
# --- Timers --------------------------------------
# timer: reading model = 0.07819599999857019
# timer: setting model = 0.0013583510008174926
# timer: shortchar 0   = 0.08123624500149162
# timer: feautrier 2   = 0.4994072160006908
# -------------------------------------------------

# %%
tools.relative_error(im, im_a)
# Out:
# array([[[-1.01210070e-05, -1.01211650e-05, -1.01212954e-05, ...,
#          -1.16161136e-05, -1.08927060e-05, -1.02833855e-05],
#         [-1.00187855e-05, -1.00189419e-05, -1.00190710e-05, ...,
#           7.49294758e-05,  1.85439276e-05, -5.89236168e-06],
#         [-9.91656370e-06, -9.91671853e-06, -9.91684630e-06, ...,
#           1.62860883e-04,  5.00878728e-05, -7.69140217e-07],
#         ...,
#         [-2.04205282e-07, -2.04208475e-07, -2.04211109e-07, ...,
#           1.47708119e-03,  1.47707978e-03,  1.47707806e-03],
#         [-1.01956368e-07, -1.01957964e-07, -1.01959281e-07, ...,
#           1.47718351e-03,  1.47718210e-03,  1.47718038e-03],
#         [ 2.92829855e-10,  2.92829852e-10,  2.92829857e-10, ...,
#           1.47728583e-03,  1.47728442e-03,  1.47728270e-03]]],
#       dtype=float128)
