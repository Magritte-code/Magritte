# %% [markdown]
# # Overview of Numeric Benchmarks
# ---

# %% [markdown]
# ### van Zadelhoff 1 3D mesher
# ---

# %%
from vanZadelhoff_1_3D_mesher import create_model, run_model, run_test
# run_test()
# Out:
# Info    : Running 'gmsh /home/frederik/Dropbox/GitHub/Magritte/tests/benchmarks/numeric/../../models//vanZadelhoff_1_3D_mesher.geo -3 -saveall -o /home/frederik/Dropbox/GitHub/Magritte/tests/benchmarks/numeric/../../models//vanZadelhoff_1_3D_mesher.vtk' [Gmsh 4.4.1, 1 node, max. 1 thread]
# Info    : Started on Tue Dec  8 17:23:26 2020
# Info    : Reading '/home/frederik/Dropbox/GitHub/Magritte/tests/benchmarks/numeric/../../models//vanZadelhoff_1_3D_mesher.geo'...
# Info    : Done reading '/home/frederik/Dropbox/GitHub/Magritte/tests/benchmarks/numeric/../../models//vanZadelhoff_1_3D_mesher.geo'
# Info    : Meshing 1D...
# Info    : Meshing curve 101 (Circle)
# Info    : Meshing curve 102 (Circle)
# Info    : Meshing curve 103 (Circle)
# Info    : Meshing curve 104 (Circle)
# Info    : Meshing curve 105 (Circle)
# Info    : Meshing curve 106 (Circle)
# Info    : Meshing curve 107 (Circle)
# Info    : Meshing curve 108 (Circle)
# Info    : Meshing curve 109 (Circle)
# ...

# %%
import meshio

# %%
meshio.__version__
# Out:
# '4.3.6'

# %%
m = meshio.read('../../models/vanZadelhoff_1_3D_mesher.vtk')

# %%
m.points
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 1.00000000e+13,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  1.00000000e+13,  0.00000000e+00],
#        ...,
#        [-7.26098149e+15,  1.70261961e+16, -1.59192430e+16],
#        [-3.89792554e+15,  5.54757257e+16,  2.47221126e+16],
#        [ 1.57051740e+16, -1.70448137e+16, -1.08886446e+16]])
