# %% [markdown]
# #  Create AGB model Jan reduction
# ---

# %% [markdown]
# The original model contains more points than we need (see e.g. [De Ceuster et al. 2020](https://arxiv.org/abs/2011.14998)). Therfore we will try to reduce it.

# %% [markdown]
# ## Imports

# %%
import yt
import vtk
import h5py
import meshio
import numpy           as np
import magritte.setup  as setup
import magritte.mesher as mesher
import magritte.core   as magritte

from tqdm                   import tqdm
from astropy                import constants
from vtk.util.numpy_support import vtk_to_numpy
from scipy.spatial          import Delaunay, cKDTree
from numba                  import njit
from yt.funcs               import mylog
mylog.setLevel(40) # This sets the log level to "ERROR"
# Out:
# /home/thomas/anaconda3/envs/magritte/lib/python3.7/_collections_abc.py:666: MatplotlibDeprecationWarning: The global colormaps dictionary is no longer considered public API.
#   self[key]

# %% [markdown]
# ## Reduce mesh

# %%
with h5py.File('model_Jan.hdf5') as file:
    pos = np.array(file['geometry/points/position'        ], dtype = np.float64)
    nbs = np.array(file['geometry/points/neighbors'       ], dtype = np.int64  )
    nns = np.array(file['geometry/points/n_neighbors'     ], dtype = np.int64  )
    bdy = np.array(file['geometry/boundary/boundary2point'], dtype = np.int64  )
    nCO = np.array(file['chemistry/species/abundance'     ], dtype = np.float64)[:,1]

# %%
delaunay = Delaunay(pos)

# %%
@njit
def get_pfs (nns):
    pfs = np.zeros(nns.shape, dtype=np.int64)
    tot = 0
    for i, n in enumerate(nns):
        tot    += n
        pfs[i]  = tot
    return pfs
        
@njit
def get_nbs (nbs, pfs, i):
    if (i == 0):
        return nbs[0:pfs[0]]
    else:
        return nbs[pfs[i-1]:pfs[i]]

@njit
def norm (vec_arr):
    norms = np.zeros(vec_arr.shape[0])
    for i in range(vec_arr.shape[0]):
        for j in range(vec_arr.shape[1]):
            norms[i] = norms[i] + vec_arr[i,j]**2
    return np.sqrt(norms)

@njit
def get_Gs (tracer, nbs, pfs):
    Gs = np.zeros(tracer.shape[0])
    for i in range(tracer.shape[0]):
        tracer_i = tracer[i]
        tracer_n = tracer[get_nbs(nbs, pfs, i)]
        Gs[i] = np.max(np.abs(tracer_i - tracer_n) / (tracer_i + tracer_n))
    return Gs
        
@njit
def get_Ls (pos, nbs, pfs):
    Ls = np.zeros(pos.shape[0])
    for i in range(pos.shape[0]):
        Ls[i] = np.mean(norm(pos[i] - pos[get_nbs(nbs, pfs, i)]))
    return Ls

@njit
def get_weight (pos, nbs, nns, tracer, threshold=0.21, fmin=1.0, ftarget=2.15):

    pfs = get_pfs (nns)
    GGs = get_Gs  (tracer, nbs, pfs)
    LLs = get_Ls  (pos,    nbs, pfs)
    
    L_min    = fmin    * LLs
    L_target = ftarget * LLs
    
    weight = L_target
    weight[GGs > threshold] = L_min[GGs > threshold]

    return weight


# Define an outer boundary for the model
bound = 0.99 * np.min(np.linalg.norm(pos[bdy], axis=1))

# %%
meshName  = 'model_Jan_reduced'
scale_max = 1.0e+99
scale_min = 0.0
threshold = 0.21
fmin      = 1.0       # don't allow refinenment 
ftarget   = 2.15      # approx 10^(-1/3) for approx 10 times fewer points 

# Create a background mesh (in .mesh format)
meshio.write_points_cells(
    filename   = f'{meshName}.msh',
    points     =             delaunay.points,
    cells      = {'tetra'  : delaunay.simplices},
    point_data = {'weights': get_weight(pos=pos, nbs=nbs, nns=nns, tracer=nCO, threshold=threshold, fmin=fmin, ftarget=ftarget)}
)

# Convert .msh to .pos mesh for Gmsh
mesher.convert_msh_to_pos (meshName=meshName, replace=True)

# Create a new mesh from the background mesh
mesher.create_mesh_from_background(
    meshName  = meshName,
    boundary  = mesher.boundary_sphere(radius=bound),
    scale_min = scale_min,
    scale_max = scale_max
)
# Out:
# WARNING:root:Binary Gmsh needs c_size_t (got int32). Converting.
# Info    : Running 'gmsh -0 model_Jan_reduced_convert_to_pos.geo' [Gmsh 4.6.0, 1 node, max. 1 thread]
# Info    : Started on Thu Apr 22 09:37:11 2021
# Info    : Reading 'model_Jan_reduced_convert_to_pos.geo'...
# Info    : Reading 'model_Jan_reduced.msh'...
# Info    : 297984 nodes
# Info    : [  0%] Creating discrete volume 0
# Info    : 2099251 elements
# Info    : Done reading 'model_Jan_reduced.msh'
# Info    : Writing 'model_Jan_reduced.pos'...
# Info    : Done writing 'model_Jan_reduced.pos'
# Info    : Done reading 'model_Jan_reduced_convert_to_pos.geo'
# Info    : Writing 'model_Jan_reduced_convert_to_pos.geo_unrolled'...
# Info    : Done writing 'model_Jan_reduced_convert_to_pos.geo_unrolled'
# Info    : Stopped on Thu Apr 22 09:37:35 2021 (From start: Wall 23.8517s, CPU 23.0285s)
# Info    : Running 'gmsh model_Jan_reduced.geo -3 -saveall -o model_Jan_reduced.vtk' [Gmsh 4.6.0, 1 node, max. 1 thread]
# Info    : Started on Thu Apr 22 09:37:35 2021
# Info    : Reading 'model_Jan_reduced.geo'...
# Info    : Reading 'model_Jan_reduced.pos'...
# Info    : Done reading 'model_Jan_reduced.pos'
# Info    : Done reading 'model_Jan_reduced.geo'
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 101 (Circle)
# Info    : [ 10%] Meshing curve 102 (Circle)
# Info    : [ 20%] Meshing curve 103 (Circle)
# Info    : [ 30%] Meshing curve 104 (Circle)
# Info    : [ 40%] Meshing curve 105 (Circle)
# Info    : [ 50%] Meshing curve 106 (Circle)
# Info    : [ 50%] Meshing curve 107 (Circle)
# Info    : [ 60%] Meshing curve 108 (Circle)
# Info    : [ 70%] Meshing curve 109 (Circle)
# Info    : [ 80%] Meshing curve 110 (Circle)
# Info    : [ 90%] Meshing curve 111 (Circle)
# Info    : [100%] Meshing curve 112 (Circle)
# Info    : Done meshing 1D (Wall 2.15809s, CPU 2.11025s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 114 (Surface, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 116 (Surface, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 118 (Surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 120 (Surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 122 (Surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 124 (Surface, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 126 (Surface, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 128 (Surface, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0771909s, CPU 0.069387s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 1 volume with 1 connected component
# Info    : Tetrahedrizing 1473 nodes...
# Info    : Done tetrahedrizing 1481 nodes (Wall 0.0171778s, CPU 0.016816s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.031116s, CPU 0.030755s)
# Info    : Found volume 130
# Info    : It. 0 - 0 nodes created - worst tet radius 24.9816 (nodes removed 0 0)
# Info    : It. 500 - 500 nodes created - worst tet radius 3.79044 (nodes removed 0 0)
# Info    : It. 1000 - 1000 nodes created - worst tet radius 3.31952 (nodes removed 0 0)
# Info    : It. 1500 - 1500 nodes created - worst tet radius 2.69426 (nodes removed 0 0)
# Info    : It. 2000 - 2000 nodes created - worst tet radius 2.3862 (nodes removed 0 0)
# Info    : It. 2500 - 2500 nodes created - worst tet radius 2.22409 (nodes removed 0 0)
# Info    : It. 3000 - 3000 nodes created - worst tet radius 2.09382 (nodes removed 0 0)
# Info    : It. 3500 - 3500 nodes created - worst tet radius 1.99258 (nodes removed 0 0)
# Info    : It. 4000 - 4000 nodes created - worst tet radius 1.91419 (nodes removed 0 0)
# Info    : It. 4500 - 4500 nodes created - worst tet radius 1.84573 (nodes removed 0 0)
# Info    : It. 5000 - 5000 nodes created - worst tet radius 1.78696 (nodes removed 0 0)
# Info    : It. 5500 - 5500 nodes created - worst tet radius 1.73474 (nodes removed 0 0)
# Info    : It. 6000 - 6000 nodes created - worst tet radius 1.68263 (nodes removed 0 0)
# Info    : It. 6500 - 6500 nodes created - worst tet radius 1.6426 (nodes removed 0 0)
# Info    : It. 7000 - 7000 nodes created - worst tet radius 1.60274 (nodes removed 0 0)
# Info    : It. 7500 - 7500 nodes created - worst tet radius 1.56415 (nodes removed 0 0)
# Info    : It. 8000 - 8000 nodes created - worst tet radius 1.53286 (nodes removed 0 0)
# Info    : It. 8500 - 8500 nodes created - worst tet radius 1.50219 (nodes removed 0 0)
# Info    : It. 9000 - 9000 nodes created - worst tet radius 1.47088 (nodes removed 0 0)
# Info    : It. 9500 - 9500 nodes created - worst tet radius 1.5629 (nodes removed 0 0)
# Info    : It. 10000 - 10000 nodes created - worst tet radius 1.42384 (nodes removed 0 0)
# Info    : It. 10500 - 10500 nodes created - worst tet radius 1.40145 (nodes removed 0 0)
# Info    : It. 11000 - 11000 nodes created - worst tet radius 1.37862 (nodes removed 0 0)
# Info    : It. 11500 - 11500 nodes created - worst tet radius 1.35836 (nodes removed 0 0)
# Info    : It. 12000 - 12000 nodes created - worst tet radius 1.34056 (nodes removed 0 0)
# Info    : It. 12500 - 12500 nodes created - worst tet radius 1.32219 (nodes removed 0 0)
# Info    : It. 13000 - 13000 nodes created - worst tet radius 1.30472 (nodes removed 0 0)
# Info    : It. 13500 - 13500 nodes created - worst tet radius 1.28959 (nodes removed 0 0)
# Info    : It. 14000 - 14000 nodes created - worst tet radius 1.38214 (nodes removed 0 0)
# Info    : It. 14500 - 14500 nodes created - worst tet radius 1.25804 (nodes removed 0 0)
# Info    : It. 15000 - 15000 nodes created - worst tet radius 1.24536 (nodes removed 0 0)
# Info    : It. 15500 - 15500 nodes created - worst tet radius 1.23208 (nodes removed 0 0)
# Info    : It. 16000 - 16000 nodes created - worst tet radius 1.21964 (nodes removed 0 0)
# Info    : It. 16500 - 16500 nodes created - worst tet radius 1.20688 (nodes removed 0 0)
# Info    : It. 17000 - 17000 nodes created - worst tet radius 1.19506 (nodes removed 0 0)
# Info    : It. 17500 - 17500 nodes created - worst tet radius 1.18372 (nodes removed 0 0)
# Info    : It. 18000 - 18000 nodes created - worst tet radius 1.17256 (nodes removed 0 0)
# Info    : It. 18500 - 18500 nodes created - worst tet radius 1.16184 (nodes removed 0 0)
# Info    : It. 19000 - 19000 nodes created - worst tet radius 1.15137 (nodes removed 0 0)
# Info    : It. 19500 - 19500 nodes created - worst tet radius 1.14075 (nodes removed 0 0)
# Info    : It. 20000 - 20000 nodes created - worst tet radius 1.14103 (nodes removed 0 0)
# Info    : It. 20500 - 20500 nodes created - worst tet radius 1.12241 (nodes removed 0 0)
# Info    : It. 21000 - 21000 nodes created - worst tet radius 1.11382 (nodes removed 0 0)
# Info    : It. 21500 - 21500 nodes created - worst tet radius 1.10558 (nodes removed 0 0)
# Info    : It. 22000 - 22000 nodes created - worst tet radius 1.09753 (nodes removed 0 0)
# Info    : It. 22500 - 22500 nodes created - worst tet radius 1.12374 (nodes removed 0 0)
# Info    : It. 23000 - 23000 nodes created - worst tet radius 1.08127 (nodes removed 0 0)
# Info    : It. 23500 - 23500 nodes created - worst tet radius 1.07248 (nodes removed 0 0)
# Info    : It. 24000 - 24000 nodes created - worst tet radius 1.06457 (nodes removed 0 0)
# Info    : It. 24500 - 24500 nodes created - worst tet radius 1.1435 (nodes removed 0 0)
# Info    : It. 25000 - 25000 nodes created - worst tet radius 1.05071 (nodes removed 0 0)
# Info    : It. 25500 - 25500 nodes created - worst tet radius 1.04383 (nodes removed 0 0)
# Info    : It. 26000 - 26000 nodes created - worst tet radius 1.03731 (nodes removed 0 0)
# Info    : It. 26500 - 26500 nodes created - worst tet radius 1.03016 (nodes removed 0 0)
# Info    : It. 27000 - 27000 nodes created - worst tet radius 1.02389 (nodes removed 0 0)
# Info    : It. 27500 - 27500 nodes created - worst tet radius 1.01745 (nodes removed 0 0)
# Info    : It. 28000 - 28000 nodes created - worst tet radius 1.01156 (nodes removed 0 0)
# Info    : It. 28500 - 28500 nodes created - worst tet radius 1.00583 (nodes removed 0 0)
# Info    : It. 29000 - 29000 nodes created - worst tet radius 1.00011 (nodes removed 0 0)
# Info    : 3D refinement terminated (30485 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 187797 tetrahedra created in 1.45593 sec. (128987 tets/s)
# Info    : Done meshing 3D (Wall 1.82921s, CPU 1.80486s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 130
# Info    : Optimization starts (volume = 1.54082e+39) with worst = 0.00225954 / average = 0.762404:
# Info    : 0.00 < quality < 0.10 :       406 elements
# Info    : 0.10 < quality < 0.20 :      1259 elements
# Info    : 0.20 < quality < 0.30 :      2372 elements
# Info    : 0.30 < quality < 0.40 :      3849 elements
# Info    : 0.40 < quality < 0.50 :      6369 elements
# Info    : 0.50 < quality < 0.60 :     11705 elements
# Info    : 0.60 < quality < 0.70 :     23286 elements
# Info    : 0.70 < quality < 0.80 :     44220 elements
# Info    : 0.80 < quality < 0.90 :     62005 elements
# Info    : 0.90 < quality < 1.00 :     32326 elements
# Info    : 3954 edge swaps, 157 node relocations (volume = 1.54082e+39): worst = 0.186136 / average = 0.774844 (Wall 0.109127s, CPU 0.109115s)
# Info    : 3976 edge swaps, 160 node relocations (volume = 1.54082e+39): worst = 0.255713 / average = 0.774893 (Wall 0.138151s, CPU 0.138086s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         2 elements
# Info    : 0.30 < quality < 0.40 :      3782 elements
# Info    : 0.40 < quality < 0.50 :      6196 elements
# Info    : 0.50 < quality < 0.60 :     11592 elements
# Info    : 0.60 < quality < 0.70 :     23455 elements
# Info    : 0.70 < quality < 0.80 :     44932 elements
# Info    : 0.80 < quality < 0.90 :     62316 elements
# Info    : 0.90 < quality < 1.00 :     32058 elements
# Info    : Done optimizing mesh (Wall 0.373998s, CPU 0.369925s)
# Info    : 30486 nodes 187458 elements
# Info    : Writing 'model_Jan_reduced.vtk'...
# Info    : Done writing 'model_Jan_reduced.vtk'
# Info    : Stopped on Thu Apr 22 09:37:49 2021 (From start: Wall 14.0634s, CPU 13.8016s)

# %% [markdown]
# ## Create a reduced Magritte model

# %%
vtk_file   = 'model_Jan_reduced.vtk'
model_file = 'model_Jan_reduced.hdf5'
lamda_file = '../data/co.txt'

# %%
# Load the mesh created above
mesh = mesher.Mesh(vtk_file)

# Set model parameters
dimension = 3
npoints   = mesh.points.shape[0]
nrays     = 12*1*1
nspecs    = 5
nlspecs   = 1
nquads    = 5 # minimum recommended by frederik
# nquads    = 1 #for testing where errors lie, the lower the better

# "Interpolate" (effectively just map the points)
corresp_points = cKDTree(pos).query(mesh.points)[1]

# Load original model
model = magritte.Model('model_Jan.hdf5')

# Map data
position = np.array(model.geometry.points.position        )[corresp_points]
velocity = np.array(model.geometry.points.velocity        )[corresp_points]
nCO      = np.array(model.chemistry.species.abundance     )[corresp_points,1]
nH2      = np.array(model.chemistry.species.abundance     )[corresp_points,2]
tmp      = np.array(model.thermodynamics.temperature.gas  )[corresp_points]
trb      = np.array(model.thermodynamics.turbulence.vturb2)[corresp_points]

# Extract Delaunay vertices (= Voronoi neighbors)
delaunay = Delaunay(position)
(indptr, indices) = delaunay.vertex_neighbor_vertices
neighbors = [indices[indptr[k]:indptr[k+1]] for k in range(npoints)]
nbs       = [n for sublist in neighbors for n in sublist]
n_nbs     = [len(sublist) for sublist in neighbors]

# Convenience arrays
zeros = np.zeros(npoints)
ones  = np.ones (npoints)
# Out:
# 0
# /home/thomas/anaconda3/envs/magritte/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
model = magritte.Model ()
model.parameters.set_spherical_symmetry(False)
model.parameters.set_pop_prec          (1.0e-6)
model.parameters.set_model_name        (model_file)
model.parameters.set_dimension         (dimension)
model.parameters.set_npoints           (npoints)
model.parameters.set_nrays             (nrays)
model.parameters.set_nspecs            (nspecs)
model.parameters.set_nlspecs           (nlspecs)
model.parameters.set_nquads            (nquads)

model.geometry.points.position.set(position)
model.geometry.points.velocity.set(velocity)

#model.geometry.points.  neighbors.set(  nbs)
#model.geometry.points.n_neighbors.set(n_nbs)
model.geometry.points.multiscale.set_all_neighbors(n_nbs,nbs)

model.chemistry.species.abundance = np.array((zeros, nCO, nH2, zeros, ones)).T
model.chemistry.species.symbol    = ['dummy0', 'CO', 'H2', 'e-', 'dummy1']

model.thermodynamics.temperature.gas  .set(tmp)
model.thermodynamics.turbulence.vturb2.set(trb)

model.parameters.set_nboundary(len(mesh.boundary))
model.geometry.boundary.boundary2point.set(mesh.boundary)

model = setup.set_boundary_condition_CMB  (model)
model = setup.set_uniform_rays            (model)
model = setup.set_linedata_from_LAMDA_file(model, lamda_file)
model = setup.set_quadrature              (model)

model.write()

# %%
quantity = 'n_mol'

ds = yt.load_unstructured_mesh(
         connectivity = mesh.tetras.astype(np.int64),
         coordinates  = mesh.points.astype(np.float64),
         node_data    = {('connect1', quantity): nCO[mesh.tetras].astype(np.float64)}
)

sl = yt.SlicePlot(ds, 'z', quantity)
sl.set_log             (quantity, True)
sl.set_cmap            (quantity, 'magma')
sl.zoom                (1)
sl.annotate_mesh_lines (plot_args={'color':'lightgrey', 'linewidths':[.2]})
# Out:
# /home/thomas/anaconda3/envs/magritte/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/thomas/anaconda3/envs/magritte/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/thomas/anaconda3/envs/magritte/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# As we can see, this model contains far fewer points.

# %%
model.parameters.npoints()
# Out:
# 30485
