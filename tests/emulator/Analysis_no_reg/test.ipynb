# %%
import numpy as np
import matplotlib.pyplot as plt

for i in range(2, 8):
    p = np.load(str(i)+"_order_0.npy")
    print(i , len(p))
    plt.plot(np.arange(len(p)), p , label = str(i)+" order")
    plt.yscale("log")
    plt.title("Anderson Acc. for different orders with regression term $\lambda = 0$")
    plt.legend()
    plt.ylabel("max_diff")
    plt.xlabel("iteration_step")
    plt.show()
# Out:
# 2 100
# 3 38
# 4 32
# 5 30
# 6 28
# 7 30

# %%
for p in range(2,8):
    fig1 = plt.figure(p-1)
    arr = np.load("C_"+str(p)+"order_0.npy")
    print(arr)
    c = []
    for i in range(0, len(arr)-1):
        t = arr[i+1] - arr[i]
        t = np.sum(t)
        t = t**2
        c.append(t)
    #print(np.arange(len(c)))
    #plt.plot(np.arange(len(c)), c , 'ro')
    plt.stem(np.arange(len(c)),c , "ro")
    plt.yscale("log")
    plt.show()
# Out:
# [[  0.34707803  -1.9452038    2.598126  ]
#  [ -0.06966322  -0.06965943   1.1393226 ]
#  [  0.667533     0.6675207   -0.33505362]
#  [  0.28274977   0.2827513    0.4344989 ]
#  [  0.33061573   0.33061618   0.33876812]
#  [  0.3195607    0.31956103   0.36087826]
#  [  0.32206446   0.3220648    0.35587078]
#  [  0.3043256    0.30432636   0.391348  ]
#  [  0.33285692   0.33285713   0.3342859 ]
#  [  0.33111385   0.33111396   0.33777222]
#  [  0.36788058   0.36787957   0.26423988]
#  [  0.290925     0.29092634   0.41814864]
#  [  0.46371615   0.4637112    0.07257262]
#  [  1.2522882    1.2522559   -1.5045441 ]
#  [-28.041084   -28.040123    57.081207  ]
#  [  0.6151016    0.61509216  -0.23019372]
#  [  2.6353714    2.6352952   -4.2706666 ]
#  [  0.11348757   0.11349483   0.77301764]
#  [  0.40816852   0.40816578   0.18366575]
#  [  0.3153452    0.3153458    0.369309  ]
#  [  0.3250689    0.32506928   0.34986183]
#  [  0.31875852   0.3187589    0.36248255]]
# ...
